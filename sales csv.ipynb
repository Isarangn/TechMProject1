# %%
import pandas as pd

# %%
df = pd.read_csv('sales_04215.csv')
df
# Out:
#                              Region            Country      Item_Type  \
# 0      Middle East and North Africa              Yemen      Household
# 1                            Europe             Norway         Cereal
# 2                Sub-Saharan Africa           Tanzania         Cereal
# 3                              Asia              China      Beverages
# 4                Sub-Saharan Africa              Kenya  Personal Care
# ...                             ...                ...            ...
# 38412         Australia and Oceania              Tonga         Snacks
# 38413            Sub-Saharan Africa           Zimbabwe      Household
# 38414                          Asia         Bangladesh     Vegetables
# 38415                        Europe            Armenia      Household
# 38416            Sub-Saharan Africa  Equatorial Guinea         Snacks
#
#       Sales_Channel Order_Priority  Order_Date   Order_ID   Ship_Date  \
# ...

# %%
df.shape
# Out:
# (38417, 14)

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Order_Date', 'Order_ID', 'Ship_Date', 'Units_Sold', 'Unit_Price',
#        'Unit_Cost', 'Total_Revenue', 'Total_Cost', 'Total_Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38417 entries, 0 to 38416
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          38417 non-null  object
#  1   Country         38417 non-null  object
#  2   Item_Type       38417 non-null  object
#  3   Sales_Channel   38417 non-null  object
#  4   Order_Priority  38417 non-null  object
#  5   Order_Date      38417 non-null  object
#  6   Order_ID        38417 non-null  int64
#  7   Ship_Date       38417 non-null  object
#  8   Units_Sold      38417 non-null  int64
#  9   Unit_Price      38417 non-null  float64
#  10  Unit_Cost       38417 non-null  float64
#  11  Total_Revenue   38417 non-null  float64
#  12  Total_Cost      38417 non-null  float64
#  13  Total_Profit    38417 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 4.1+ MB

# %%
# chaking missing values
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item_Type         0
# Sales_Channel     0
# Order_Priority    0
# Order_Date        0
# Order_ID          0
# Ship_Date         0
# Units_Sold        0
# Unit_Price        0
# Unit_Cost         0
# Total_Revenue     0
# Total_Cost        0
# Total_Profit      0
# dtype: int64

# %%
df.describe()
# Out:
#            Order_ID    Units_Sold    Unit_Price     Unit_Cost  Total_Revenue  \
# count  3.841700e+04  38417.000000  38417.000000  38417.000000   3.841700e+04
# mean   5.497129e+08   4999.918343    266.287374    187.608052   1.331390e+06
# std    2.594917e+08   2887.230630    216.966818    175.578002   1.469094e+06
# min    1.000518e+08      1.000000      9.330000      6.920000   9.330000e+00
# 25%    3.248647e+08   2503.000000    109.280000     35.840000   2.793108e+05
# 50%    5.493235e+08   5003.000000    205.700000    117.110000   7.866617e+05
# 75%    7.740588e+08   7503.000000    437.200000    263.330000   1.822913e+06
# max    9.999741e+08   9999.000000    668.270000    524.960000   6.682032e+06
#
#          Total_Cost  Total_Profit
# count  3.841700e+04  3.841700e+04
# mean   9.378587e+05  3.935310e+05
# std    1.148479e+06  3.799255e+05
# min    6.920000e+00  2.410000e+00
# 25%    1.626274e+05  9.569560e+04
# 50%    4.688813e+05  2.822382e+05
# ...

# %%
df['Order_Date'].min()
# Out:
# '01-04-2015'

# %%
df['Order_Date'].max()
# Out:
# '30-04-2015'

# %%
region_tot = df.groupby(['Region'])['Total_Revenue','Total_Cost','Total_Profit'].sum().reset_index()
region_tot
# Out:
# <ipython-input-45-d6fcced688d2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   region_tot = df.groupby(['Region'])['Total_Revenue','Total_Cost','Total_Profit'].sum().reset_index()
#                               Region  Total_Revenue    Total_Cost  \
# 0                               Asia   7.441767e+09  5.240402e+09
# 1              Australia and Oceania   4.107218e+09  2.884104e+09
# 2  Central America and the Caribbean   5.523574e+09  3.883471e+09
# 3                             Europe   1.328603e+10  9.368416e+09
# 4       Middle East and North Africa   6.449462e+09  4.543363e+09
# 5                      North America   1.139754e+09  8.072569e+08
# 6                 Sub-Saharan Africa   1.320019e+10  9.302706e+09
#
#    Total_Profit
# 0  2.201366e+09
# 1  1.223114e+09
# 2  1.640103e+09
# 3  3.917619e+09
# 4  1.906099e+09
# 5  3.324974e+08
# 6  3.897482e+09

# %%
region_unit = df.groupby(['Region'])['Sales_Channel','Units_Sold'].sum().reset_index()
region_unit
# Out:
# <ipython-input-40-ace776025b88>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   region_unit = df.groupby(['Region'])['Sales_Channel','Units_Sold'].sum().reset_index()
#                               Region  Units_Sold
# 0                               Asia    28080431
# 1              Australia and Oceania    15614033
# 2  Central America and the Caribbean    20728463
# 3                             Europe    49898760
# 4       Middle East and North Africa    24093705
# 5                      North America     4097453
# 6                 Sub-Saharan Africa    49569018

# %%
rep1 = pd.DataFrame(region_tot)
rep1.to_csv('report1.csv')

# %%
rep2 = pd.DataFrame(region_unit)
rep2.to_csv('report2.csv')
